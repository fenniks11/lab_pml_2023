# %% [markdown]
# # Perceptron
# **Buatlah penyelesaian dan perhitungannya, lalu cara perhitungan dikonversi ke bahasa program python dan dijalankan di Jupyter Notebook.**

# %% [markdown]
# 1. Buatlah jaringan syaraf tiruan menggunakan konsep perceptron untuk mengenali logika **AND** pada input dan output bipolar. Dengan ketentuan, nilai bobot(w) dan bias(b) = 0, nilai learning rate = 1 dan threshold = 0.3.
#
# 2. Buatlah jaringan syaraf tiruan menggunakan konsep perceptron untuk mengenali logika **OR** pada input dan output bipolar. Dengan ketentuan, nilai bobot(w) dan bias(b) = 0, nilai learning rate = 1 dan threshold = 0.
#
# 3. Buatlah jaringan syaraf tiruan menggunakan konsep perceptron untuk mengenali logika **AND** pada input dan output biner. Dengan ketentuan, nilai bobot(w) dan bias(b) = 0, nilai learning rate = 1 dan threshold = 0.3.
#
# 4. Buatlah jaringan syaraf tiruan menggunakan konsep perceptron untuk mengenali logika **OR** pada input dan output biner. Dengan ketentuan, nilai bobot(w) dan bias(b) = 0, nilai learning rate = 1 dan threshold = 0.
#
# 5. Buatlah jaringan syaraf tiruan menggunakan konsep perceptron untuk mengenali logika **XOR** pada input dan output bipolar. Dengan ketentuan, nilai bobot(w) dan bias(b) = 0, nilai learning rate = 1 dan threshold = 0.
#
# 6. Buatlah jaringan syaraf tiruan menggunakan konsep perceptron untuk mengenali logika **XOR** pada input dan output biner. Dengan ketentuan, nilai bobot(w) dan bias(b) = 0, nilai learning rate = 1 dan threshold = 0.
#
# 7. Buatlah jaringan syaraf tiruan menggunakan konsep perceptron untuk mengenali logika **NAND** pada input dan output bipolar. Dengan ketentuan, nilai bobot(w) dan bias(b) = 0, nilai learning rate = 1 dan threshold = 0.3.
#
# 8. Buatlah jaringan syaraf tiruan menggunakan konsep perceptron untuk mengenali logika **NAND** pada input dan output biner. Dengan ketentuan, nilai bobot(w) dan bias(b) = 0, nilai learning rate = 1 dan threshold = 0.
#
# 9. Buatlah jaringan syaraf tiruan menggunakan konsep perceptron untuk mengenali logika **NOR** pada input dan output bipolar. Dengan ketentuan, nilai bobot(w) dan bias(b) = 0, nilai learning rate = 1 dan threshold = 0.
#
# 10. Buatlah jaringan syaraf tiruan menggunakan konsep perceptron untuk mengenali logika **NOR** pada input dan output biner. Dengan ketentuan, nilai bobot(w) dan bias(b) = 0, nilai learning rate = 1 dan threshold = 0.

# %% [markdown]
# # Delta Rule
# **Buatlah penyelesaian dan perhitungannya, lalu cara perhitungan dikonversi ke bahasa program python dan dijalankan di Jupyter Notebook.**

# %% [markdown]
# 1. Berikan gambaran jaringan syaraf tiruan dengan menggunakan delta rule untuk melakukan pembelajaran terhadap fungsi logika **OR** dengan input dan output biner. Dengan threshold = 0.2, learning rate = 0.1. Lalu bobot awal(w1) adalah 0.1, dan bobot kedua(w2) = 0.3.
#
# 2. Berikan gambaran jaringan syaraf tiruan dengan menggunakan delta rule untuk melakukan pembelajaran terhadap fungsi logika **AND** dengan input dan output biner. Dengan threshold = 0.2, learning rate = 0.1. Lalu bobot awal(w1) adalah 0.1, dan bobot kedua(w2) = 0.3.
#
# 3. Berikan gambaran jaringan syaraf tiruan dengan menggunakan delta rule untuk melakukan pembelajaran terhadap fungsi logika **OR** dengan input dan output bipolar. Dengan threshold = 0.4, learning rate = 0.3. Lalu bobot awal(w1) adalah 0.1, dan bobot kedua(w2) = 0.3.
#
# 4. Berikan gambaran jaringan syaraf tiruan dengan menggunakan delta rule untuk melakukan pembelajaran terhadap fungsi logika **OR** dengan input dan output bipolar. Dengan threshold = 0.4, learning rate = 0.3. Lalu bobot awal(w1) adalah 0.2, dan bobot kedua(w2) = 0.1.
#
# 5. Berikan gambaran jaringan syaraf tiruan dengan menggunakan delta rule untuk melakukan pembelajaran terhadap fungsi logika **AND** dengan input dan output bipolar. Dengan threshold = 0.5, learning rate = 0.1. Lalu bobot awal(w1) adalah 0.4, dan bobot kedua(w2) = 0.3.
#
# 6. Buatlah jaringan syaraf tiruan menggunakan konsep delta rule untuk melakukan pembelajaran terhadap fungsi logika **XOR** dengan input dan output biner. Dengan ketentuan, threshold = 0.5, learning rate = 0.2. Lalu bobot awal(w1) adalah 0.3, bobot kedua(w2) = 0.4, dan bobot ketiga(w3) = 0.1.
#
# 7. Buatlah jaringan syaraf tiruan menggunakan konsep delta rule untuk melakukan pembelajaran terhadap fungsi logika **NAND** dengan input dan output biner. Dengan ketentuan, threshold = 0.3, learning rate = 0.1. Lalu bobot awal(w1) adalah 0.2, bobot kedua(w2) = 0.5, dan bobot ketiga(w3) = 0.4.
#
# 8. Buatlah jaringan syaraf tiruan menggunakan konsep delta rule untuk melakukan pembelajaran terhadap fungsi logika **NOR** dengan input dan output bipolar. Dengan ketentuan, threshold = 0.6, learning rate = 0.3. Lalu bobot awal(w1) adalah 0.4, bobot kedua(w2) = 0.2, dan bobot ketiga(w3) = 0.5.
#
# 9. Buatlah jaringan syaraf tiruan menggunakan konsep delta rule untuk melakukan pembelajaran terhadap fungsi logika **XOR** dengan input dan output bipolar. Dengan ketentuan, threshold = 0.4, learning rate = 0.2. Lalu bobot awal(w1) adalah 0.3, bobot kedua(w2) = 0.1, dan bobot ketiga(w3) = 0.2.
#
# 10. Buatlah jaringan syaraf tiruan menggunakan konsep delta rule untuk melakukan pembelajaran terhadap fungsi logika **NAND** dengan input dan output bipolar. Dengan ketentuan, threshold = 0.5, learning rate = 0.1. Lalu bobot awal(w1) adalah 0.2, bobot kedua(w2) = 0.4, dan bobot ketiga(w3) = 0.3.

# %%
import pandas as pd
import random

df = pd.read_excel('ListTugas2.xlsx')
df
# Out:
#                                     Nama        NIM  Sesi  Perceptron  \
# 0                            Sri Wahyuni  191402045     1           8
# 1           Brian Christopel Simanjuntak  191402091     1           9
# 2                          Indah Safitri  201402006     1           6
# 3                  Muhammad Iqbal Manalu  201402011     1           7
# 4                  Pahwana Br Sinulingga  201402013     1           3
# 5                          Ridha Arrahmi  201402015     1           1
# 6                       Ullayya Zhafirah  201402017     1           6
# 7                           Atikah Husna  201402020     1           3
# 8                     Citra Wahyuni Amri  201402021     1           9
# 9                          Ivan Tandella  201402022     1           2
# 10           Fildzah Zata Amani Nasution  201402030     1           1
# 11                  Dorma Ulina Pasaribu  201402039     1          10
# ...
